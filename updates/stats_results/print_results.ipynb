# %%
import pandas as pd

# %%
pd.read_csv('mem_model_SME_All events HPC ca1 single_elec.csv')
# Out:
#                      name      coef    stderr          pval       tval
# 0               Intercept  0.318058  0.015510  1.869332e-93  20.506873
# 1           ripple_exists -0.002530  0.004429  5.677827e-01  -0.571320
# 2                HFA_mean  0.014658  0.002264  9.512050e-11   6.474509
# 3  ripple_exists:HFA_mean -0.011502  0.002782  3.549119e-05  -4.135028

# %%
pd.read_csv('mem_model_SME_All events HPC ca3_dg single_elec.csv')
# Out:
#                      name      coef    stderr          pval       tval
# 0               Intercept  0.313556  0.017899  1.040905e-68  17.518187
# 1           ripple_exists -0.009949  0.006334  1.162246e-01  -1.570819
# 2                HFA_mean  0.013480  0.003152  1.900224e-05   4.276303
# 3  ripple_exists:HFA_mean -0.003362  0.003860  3.837401e-01  -0.871026

# %%
pd.read_csv('mem_model_SME_All events AMY.csv')
# Out:
#                      name      coef    stderr          pval      tval
# 0               Intercept  0.296669  0.040708  3.151671e-13  7.287753
# 1           ripple_exists  0.002201  0.017191  8.981025e-01  0.128059
# 2                HFA_mean  0.022431  0.005516  4.774318e-05  4.066409
# 3  ripple_exists:HFA_mean -0.007362  0.008506  3.867583e-01 -0.865511

# %%
pd.read_csv('mem_model_SME_All events nonHPC_MTL.csv')
# Out:
#                      name      coef    stderr          pval      tval
# 0               Intercept  0.300529  0.033760  5.483639e-19  8.902026
# 1           ripple_exists -0.010410  0.015894  5.125116e-01 -0.654932
# 2                HFA_mean  0.018494  0.004482  3.679150e-05  4.126757
# 3  ripple_exists:HFA_mean -0.005498  0.004181  1.885764e-01 -1.314802
